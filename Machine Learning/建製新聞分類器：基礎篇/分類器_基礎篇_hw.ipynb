# %%
# !pip install -q -U ckiptagger[tf,gdown]

# %%
import numpy as np
import pandas as pd

from ckiptagger import data_utils
from ckiptagger import WS, POS
from tqdm.notebook import tqdm

# %%
df_train = pd.read_csv('news_clustering_train.tsv', sep='\t')
df_test = pd.read_csv('news_clustering_test.tsv', sep='\t')

# %%
df_train
# Out:
#       index class                            title
# 0         0    體育         亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列
# 1         1    體育        9輪4球本土射手僅次武磊 黃紫昌要搶最強U23頭銜
# 2         2    體育             如果今年勇士奪冠，下賽季詹姆斯何去何從？
# 3         3    體育            超級替補！科斯塔本賽季替補出場貢獻7次助攻
# 4         4    體育          騎士6天里發生了啥？從首輪搶七到次輪3-0猛龍
# ...     ...   ...                              ...
# 1795   1795    遊戲  LOL：麻辣香鍋韓服Rank不合成打野刀？電刀巨魔新套路連勝中
# 1796   1796    遊戲            穩住，我們能贏！因為我們擁有這種強大的力量
# 1797   1797    遊戲          騰訊是怎樣毀掉《鬥戰神》這款可能成神的作品的？
# 1798   1798    遊戲                   LOL你不知道的黑科技打法！
# 1799   1799    遊戲                 遊戲拳皇各代的劇情都在講些什麼？
#
# [1800 rows x 3 columns]

# %%
train_titles = {row['index']: row['title'] for _, row in df_train.iterrows()}
train_classes = {row['index']: row['class'] for _, row in df_train.iterrows()}

test_titles = {row['index']: row['title'] for _, row in df_test.iterrows()}
test_classes = {row['index']: row['class'] for _, row in df_test.iterrows()}

# %%
all_news_class = ['體育', '財經', '科技', '旅遊', '農業', '遊戲']

# %% [markdown]
# # 斷詞 + POS

# %%
data_utils.download_data_gdown("./")
ws = WS('./data/')
pos = POS('./data/')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1efHsY16pxK0lBD2gYCgCTnv1Swstq771
# To: /content/data.zip
# 1.88GB [00:13, 139MB/s]

# %%
train_title_cuts = {}
for index, title in tqdm(train_titles.items()):
    word_s = ws([title])
    word_p = pos(word_s)
    train_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1800.0), HTML(value='')))

# %%
test_title_cuts = {}
for index, title in tqdm(test_titles.items()):
    word_s = ws([title])
    word_p = pos(word_s)
    test_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=600.0), HTML(value='')))

# %%
train_title_cuts[120]
# Out:
# [('國腳', 'Na'),
#  ('張呈棟', 'Nb'),
#  ('：', 'COLONCATEGORY'),
#  ('從', 'D'),
#  ('沒', 'D'),
#  ('想', 'VE'),
#  ('過', 'Di'),
#  ('自己', 'Nh'),
#  ('會', 'D'),
#  ('出', 'VC'),
#  ('一', 'Neu'),
#  ('本', 'Nf'),
#  ('書', 'Na')]

# %% [markdown]
# # Bag of Words (BOW)

# %%
word2index = {}
# 產生字與index對應的關係
for index in train_title_cuts:
    for word, flag in train_title_cuts[index]:
        if word in word2index:
            continue
        word2index[word] = len(word2index)
index2word = {val: key for key, val in word2index.items()}

# %%
word2index['溫暖']
# Out:
# 1520

# %%
index2word[1520]
# Out:
# '溫暖'

# %%
def get_bow_vector(pairs, word2index):
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index:
            vector[word2index[word]] += 1

    return vector

# %%
get_bow_vector(train_title_cuts[120], word2index)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# # 排除較無意義的詞性

# %%
pos_analysis = {}
for _, pairs in train_title_cuts.items():
    for word, flag in pairs:
        if flag not in pos_analysis:
            pos_analysis[flag] = set()
        pos_analysis[flag].add(word)

for flag, words in pos_analysis.items():
    print(flag, ':', list(words)[:100])
    print('=======================')
# Out:
# Nb : ['電一', '穆謝奎', '史森明', '埃梅里', '科勒·卡戴珊', '馬競', '2018世界杯', '拜仁續', '朱之文', '拉基蒂奇', '樂福', '凱爾特', '章澤天', '里坦克', '娜迦王海伯倫', '扎哈維', '張良咸', '克羅托內 ', '武磊', '尼爾 ', '斯威', '密子君', '劉國梁', '勒布朗', '纏中', '秦緒文', '馬龍', '王者榮', '小強', '微星', '安德森', 'm15', '泰拳王西', '科斯塔', '男乒', '索尼', '猛', '·龜茲', '斐濟', '費基爾', '單薇恩', '加威廉', '尤納斯', '四阿哥', '魅族', '微醫', '寶二', '李嘉誠', '雲聯惠', '哈登', '奧拉朱旺遠', '北京人和', '傑尼亞', '皇馬', '德羅贊', '華峰', '扎堆', '阿木木歷', '璞麗', '伊亞', '奧拉朱旺', '安永', '馬內', '王者榮耀', '溫格', '建成', '富力', '何享健', '林美景', '萬孚', '朱嘯虎', '朱婷', '恆大', '雷霆隊', '瓜迪奧拉', '切爾西', '小詹皇', '阿里巴巴', '伏爾加格勒', '世界杯', '億航', '騰訊王', '興業', '安徒恩比盧克', '微眾', '后羿', '樊振東', '巴菲特', '濃眉哥', '高曉松', '詹皇', '星巴克', '查理芒格', '金英權', '周雲傑', '石川佳純', '刷安徒恩', '米切爾西蒙斯', '英超', '神武']
# =======================
# VC : ['替補', '放大', '看直', '存', '管理', '打', '打爆', '區分', '舉辦', '毀滅', '擺', '解決', '開復', '買賣', '製造', '購買', '評價', '生產', '報', '抽', '定', '駕馭', '認養', '構建', '纏', '營銷', '承包', '贊美', '通過', '設置', '拍到', '登頂', '打通', '養恩', '結', '發', '錄制', '取捨', '伴隨', '賞', '陪', '攀爬', '罵', '宣一', '解', '取消', '閃', '盤點', '栽種', '點', '打磨', '打響', '面試', '參透', '戲耍', '簽', '開放', '高產', '餵', '引進', '擺出', '購', '反包', '等', '踢出', '觀賞', '收取', '縮減', '守護', '認可', '下載', '調整', '改種', '食用', '打掃', '影響', '完成', '破', '進化到', '建立', '寫', '動用', '投', '燒', '攝', '參考', '隱藏', '渲染', '規劃', '挖', '擺脫', '吊打', '籌劃', '發起', '弄崩', '接', '冠絕', '套養', '練到', '大賺']
# =======================
# Na : ['牛股', '盆景', '元素', '選手', '人類', '新品', '爆文', '老人', '潮服', '身價', '現實', '資訊', '裝備', '高地', '牧歌', '烏龜', '飲水', '霸', '真因', '驍龍', '營銷', '紅心', '性價', '使用率', '紅豆', '閃電狼', '大仙', '俗話', '閃電', '大米', '精品', '樹莓', '油價', '竹林', '土地', '開心果', '玄鳳', '秘訣', '證券', '小額', '手藝', '合規性', '糧食', '大叔', '情況', '玻璃', '高峰', '塔', '宜興人', '夢淚', '運動', '水產', '惡魔', '能力', '環保', '關鍵', '漫畫', '基本', '運動員', '花式', '生意', '墊腳', '鐵路篇', '蜂', '遊戲本', '氣味', '綠色', '陣容', '網商貸', '英雄級', '德國隊', '場景', '紅綠燈', '農宿', '後衛', '成功率', '美味', '火線', '要聞', '孩子', '腳', '薪種', '油菜花', '羊', '盤', '收益率', '房產證', '蠱', '小伙', '飼料', '午餐', '菜', '行動', '刀塔', '額度', '母豬', '紀錄', '本金', '性能', '網']
# =======================
# COLONCATEGORY : [':', '：']
# =======================
# Nc : ['深圳', '四國', '山西', '太湖', '香港', '盧氏縣', '臨洮', '意大利', '冰城', '黃鶴樓', '德', '評論區', '哈尼梯田', '廣元', '實驗室', '長白山', '南寧', '風景道', '火山口', '耿店村', '沿途', '西安', '廣州', '聯合村', '上川島', '洗車店', '天際', '泰安', '賓館', '墾丁', '農科院', '天下', '中棉', '債市', '泰國', '五一', '盱眙', '農業園', '綿竹', '利希', '火焰山', '九寨', '海南', '嵐山', '烏魯木齊', '邊緣', '西藏', '萊加內斯', '母公司', '麥當勞', '央視', '浦口', '目的地', '吉隆坡', '內內', '延邊', '萊茵河', '球館', '咖啡蘭', '華中區', '嘉陵江', '唐人街', '風景區', '西安比', '市場', '國外', '聖堂山', '原地', '湖北', '南沙河鎮', '馬刺', '江夏鎮', '加州', '尼泊爾', '波密', '海口', '切爾西', '柯橋', '金融城', '國', '軍艦島', '馬德里', '牛市', '地上', '工廠', '渾江區', '分行', '瑞士', '便利店', '京東', '武漢', '貴州', '河南', '海岸', '倫貝爾', '超京', '支行', '鵬城', '國內', '世界']
# =======================
# PAUSECATEGORY : ['、']
# =======================
# VB : ['入賬', '退改', '融資', '充氣', '充飢', '罵屌絲', '收回來', '上架', '領銜', '退款', '加起來', '退貨', '定位', '加油', '分組', '解惑', '計算出來', '分段', '護航', '提前', '騙錢', '鋪平', '一網打盡', '加持', '執教', '加冕', '通話', '應對', '解圍', '代打', '開戰', '再見', '相比', '助威', '站台', '復仇', '解體', '解密', '扣分', '拍照', '加工', '導航', '抓來', '罰款', '鍍金', '分紅', '效力']
# =======================
# WHITESPACE : [' ']
# =======================
# D : ['或許', '仍然', '剛剛', '需', '越', '多', '不可以', '永', '盡', '大都', '結伴', '均', '不用', '能夠', '能', '永遠', '重新', '別', '陸續', '沒想到', '是否', '不能', '始', '預先', '沒有', '好在', '為何', '無可', '一直', '突然', '同', '專職', '可', '及時', '從未', '絕對', '直', '正', '每', '總算', '一頭', '多多', '即', '原來', '簡直', '只得', '屢', '總是', '只是', '從中', '怎麼', '只有', '全面', '為啥', '全力', '本', '該不該', '接著', '可以', '迫不及待', '居然', '親自', '一定', '真是', '並', '竟然', '很少', '先', '就', '現', '不得', '不', '不再', '冒死', '曾經', '不可', '不會', '無法', '這麼', '相', '親身', '超級', '獨', '卻', '甚至', '常常', '從', '至今', '去', '一手', '略', '未', '已然', '全程', '究竟', '即將', '盡快', '剛', '快', '天南地北']
# =======================
# P : ['自從', '憑', '於', '對', '到', '離', '距離', '給', '用', '靠', '向', '至', '就', '比如', '繼', '如', '在', '將', '根據', '往', '和', '隨了', '為了', '等', '被', '從', '比', '除了', '跟', '幫', '以', '直至', '隨', '為', '關於', '慘遭', '受', '除', '當', '針對', '趁著', '像', '自', '按', '因', '把', '待', '趁', '與', '臨', '遭']
# =======================
# VG : ['叫', '變成', '合成', '作為', '堪稱', '封號', '譽為', '排行', '彷彿', '升任', '做', '當作', '集成', '建成', '稱', '成為', '稱為', '化', '屈居', '理解為', '如', '變', '充當', '形成', '酷似', '戰成', '居', '算', '誤認成', '投票成', '疑似', '竟是', '評選', '類似', '似', '猶如', '做成', '改造成', '姓', '為', '賣成', '美成', '稱得上', '排', '當', '稱作', '算是', '等於', '名叫', '像', '當成', '並列', '非', '排名', '叫做', '成', '應聘', '屬於', '當上']
# =======================
# Neu : ['730萬', '10010', '萬', '！2018', '數千萬', '54', '100', '9-1', '2018千', '72', '1299', '2018-05-06 ', '7億', '1300', '7', '1.8億', '700', '835', '38', '98', '1.3萬', '1.1.2', '第七', '47億', '14億', '8', '42', '一千', '3.5', '2200', '1099', '幾千', '392億', '76', '一百', '100萬', '21', '5050', '十幾', '千', '十三', '4.5億', '3100', '七八千', '500', '第1', '5', '2000萬', '十萬', '56', '2萬', '二', '115', '三百', '17億', '9', '6', '六', '300萬', '3000', '七', '23萬一', '第9', '1688', '48', '50多', '1699', '1268', '第114', '2', '14', '29', '5.6千三', '200', '億', '2018', '千千萬', '30', '0.2', '30萬', '四五', '12', '幾', '90', '（四）', '11.59億', '2:3', '9-0', 'b120', '兩萬', '1.46億', ' 360', '150', '46萬', '1900億', '五一', '17', '九', '16', '24']
# =======================
# Nf : ['台', '英吋', '頁', '掛', '輪', '美元', '票', '分鐘', '處', '股', '名', '款', 'K', '本', '口', '槍', '頭', '晚', '點', '番', '則', '招', '步', '戶', '碗', '頓', '樣', '公里', '關', '鍋', '部', '個', '周', '方', '輛', '道', '畝', '屆', '年', '把', '隻', '項', '隊', '港元', '噸', '歲', '斤', '筆', '遍', '群', '串', '張', '度', '色', '班', '米', '棵', '件', '秒', '盤', '期', '回', '座', '袋', '株', '次', '家', '號', '所', '類', '場', '日', '片', '局', '毛', '對', '分', '元', '行', '檔', '條', '週', '級', '支', '門', '句', '塊', '節', '只', '套', '刻', '胎', '位', '層', '種', '路', '篇', '天', '些', '批']
# =======================
# VJ : ['看不過去', '惹不起', '抗', '不如', '含有', '錯失', '吃上', '連接', '贏下', '負於', '心疼', '領跑', '沒有', '強過', '耗', '領略', '爆發', '緊缺', '失', '降至', '受到', '領先', '沈迷', '為', '僅次於', '受', '服', '發生', '認', '歸屬於', '順應', '發揮', '熱心', '經歷', '偏愛', '減持', '獨佔', '嫌棄', '脫', '欣賞', '來自', '不到', '惜', '懷念', '缺', '喪失', '冷落', '過完', '恪守', '佔', '減', '平', '不理', '出於', '珍惜', '無', '出', '毫無', '錯過', '自有', '蘊藏', '享受', '符合', '獲', '沒', '負', '恭喜', '認識', '入圍', '得', '大勝', '持有', '替代', '高達', '翻倍', '展望', '處於', '失去', '靠', '超過', '達', '贊同', '出身', '忘懷', '逾', '適用', '達到', '忽略', '賽', '擁有', '年入', '看好', '不敵', '身臨', '歡迎', '優於', '曬', '同情', '缺少', '煥發']
# =======================
# VD : ['售', '還', '發給', '禁售', '給予', '分', '送', '寄予', '給', '借', '坑', '補貼', '速遞', '發放', '郵給', '輸', '貸款', '贏', '付', '清繳', '配', '輸給', '交付', '支付', '轉讓', '賣', '欠', '發', '供應', '借貸', '拒賠', '白送', '傳', '提供', '補繳', '予', '貸', '搶', '收費']
# =======================
# Dfa : ['多', '還', '不大', '遠', '如此', '有些', '越來越', '好', '比較', '很', '這麼', '同樣', '最', '超', '非常', '更為', '遠遠', '過於', '十分', '更', '較', '頗', '有點', '過', '還要', '太', '極']
# =======================
# VH : ['遲滯', '多', '激增', '狂野', '窘', '頭疼', '免費', '出爐', '立體', '無緣', '不錯', '色綠', '復活', '出局', '芳香', '忙', '發愁', '年久失修', '唯美', '傻眼', '養老', '便宜', '眾多', '高效', '見效', '跌停', '奇妙', '上了年紀', '肺腑獨白', '怎麼辦', '心酸', '史無前例', '變差', '積雪', '慢', '得寸進尺', '真實', '通車', '開花', '重重', '安全', '智障', '涼', '原始', '飽', '很少', '超出口', '猛', '過人', '秀麗', '完勝', '現', '那麼多', '驚恐', '空洞', '靠譜', '減產', '爆爆', '霸氣', '簡約', '火爆', '中興', '偉大', '豐收', '成年', '咸', '苦不堪言', '流暢', '爆紅', '中毒', '美味', '新', '優秀', '勝利', '未果', '長', '渾濁', '發達', '聰明', '相反', '直接', '稱霸絕', '幸福', '神奇', '迷路', '濕潤', '獲利', '完善', '濃郁', '還可以', '常見', '賞心悅目', '免息', '知名', '客平人和', '長滿', '多彩', '夠多', '低調', '健康']
# =======================
# Cbb : ['否則', '既', '跟著', '雖然', '但', '並', '不如', '縱使', '反而', '連', '即使', '可是', '還不如', '若', '既然', '要是', '就算', '而是', '但是', '假如', '不管', '因為', '不僅', '不然', '並且', '如果', '而', '因', '只要', '不過', '只有', '另外']
# =======================
# Nd : ['四月', '過去', '5月', '90年', '現代', '1日', '月季', '-5', '中旬', '週一', '現在', '長期', '00年', '31號', '短期', '15日', '旅遊節', '五月', '4日', '後期', '六', '晚上', '週二', '花季', '相親節', '13點', '採摘節', '今日', '2018', '目前', '五月份', '夏天', '夜', '2019年', '8日', '明年', '同時', '九月', '幾月份', '立夏', '首日', '春季', '2018年', '正月', '最近', '12日', '周', '中期', '小時候', '多久', '昨天', '2017年', '3月', '文化節', '6日', '一大早', '15年', '10點', '七月份', '三國', '秋', '今年', '2005年', '當前', '5.7日', '半夜', '週末', '最後', '寒武紀', '荒古', '夏季', '2035年', '隔年', '昔日', '今夏', '5日', '那時', '06日', '後來', '未來', '一會', '大中', '初夏', '晚清', '夏窗', '晚間', '當時', '狗年', '明晚', '春', '6旬', '19年', '2019', '以前', '近日', '後', '4月', '5號', '7日', '明日']
# =======================
# VA : ['隕落', '下馬', '會師', '問津', '看過來', '封卡', '變通', '做生意', '壓哨', '掙扎', '養家糊口', '登高', '血刃', '日落', '簽約', '開門紅', '保級', '扣賬', '旅行', '轉農', '建功', '上場', '摘帽', '養花', '回落', '撒沙', '格鬥', '轉賬', '起航', '作證', '墊腳', '還款', '牧育', '倒伏', '睡', '遠行', '爆錘', '伸手', '報名', '立刷', '旅遊', '釣魚', '領頭', '潛伏', '打團', '大小便', '下卡', '觀戰', '生活', '徜徉', '行走', '開業', '開課', '點贊', '進去', '點球', '面對面', '入手', '跳舞', '追債', '減稅', '做種', '打工', '喜極而泣', '育秧', '實習', '生財', '輪轉', '下海', '出門', '打卡', '喧囂', '結果', '關機', '嘗鮮', '換股', '看盤', '行', '違法', '搭檔', '加菜', '閉嘴', '下班', '字字珠璣', '跑', '騎車', '游水', '何去何從', '革命', '艷遇', '播種', '卡', '出來', '反彈', '答復', '拼房', '退票', '露營', '掉幀', '抄底']
# =======================
# COMMACATEGORY : [',', '，']
# =======================
# Nes : ['首', '本', '何', '上', '另', '某', '下', '前', '頭', '後', '該', '各', '同', '貴', '每', '近']
# =======================
# QUESTIONCATEGORY : ['？']
# =======================
# EXCLAMATIONCATEGORY : ['!', '！']
# =======================
# Di : ['過', '著', '了', '起來', '個']
# =======================
# Nep : ['那', '什麼', '啥', '哪', '其', '其中', '這', '此']
# =======================
# Caa : ['比', '又', '跟', 'VS', '到', '或', '暨', '及', '和', '還是', '與', '至', '或是', '或者']
# =======================
# VCL : ['入', '留在', '前往', '重返', '抵達', '進入', '到', '來到', '重回', '存進', '出發到', '跌出', '跌至', '穿透', '住', '栽進', '蒞臨', '到達', '走進', '走到', '在', '升至', '走訪', '遠離', '往', '回', '橫掃', '去', '回歸', '用於', '走過', '出', '暗渡', '深入', '遊覽', '穿越', '退出', '登陸', '赴', '上', '進', '穿過', '路過', '直達', '過', '前來', '回到', '盤踞', '走下', '度過', '玩遍']
# =======================
# Neqa : ['多', '9.89%', '67%', '更多', '遍', '有些', '任何', '步步', '41.8%', '這麼多', '哪些', '一處處', '無數', '80%', '部分', '所有', '其他', '15%', '其它', '一點', '百分之八十', '四成', '1%', '8%', '一切', '許多', '大量', '個個', '大多', '三分之一', '多點', '半', '90%', '這些', '30%', '100%', '不少', '那些', '全', '一半', '句句', '有的', '1/4', '大多數', '滴滴', '10%', '0.8%', '多少', '一些', '很多', '12%', '6%', '20%']
# =======================
# Nh : ['誰', '父子倆', '別人', '自身', '屌絲', '你們', '自我', '她們', '他們', '俺們', '各自', '對方', '一方', '他', '您', '私人', '你', '人家', '我', '大家', '個人', '它們', '我們', '小眾', '她', '本人', '各位', '它', '雙方', '自己']
# =======================
# FW : ['Rookie', 'BAT', '6 10.5', 'vs', 'Alan', '6G+', 'Q', 'T+0', 'PPP', 'dota', 'raid', 'Cotswolds', ' 樂', 'i7', 'Kitty', 'DW', 'King James', 'Rank', 'QG', 'mix2', 'ADC', ' + ', 'NBA ', 'DNF：', 'app', 'GPP', 'XQ', ' CCR', '5G', 'mAh+', 'Xbox ', 'SSG', 'Uzi', 'mc', 'adc', 'CCTV5', ' VS ', 'BCH', 'IP', 'vip', 'NPC', 'Lol里', 'CCR', 'RPG', 'Disneyland', 'h', 'CP', ' 展', 'K', 'AP', 'KV', 'X', '+7', 'EOS', '：AG', 'VR', '9A91', 'CDR', 'Kakao', 'qq', 'Instagram', '2', 'VS', 'SIo', 'RNG', 'Minecraft', 'B', ' vs 利物浦', 'WF', '！DOTA2 MOD', 'LOL：', 'wifi', 'DNF', '-0', 'kpl', 'FF ', 'S11', 'MARVEL X', 'G+', 'e', 'Hello ', 'QM', 'Ghappy', '-6', 'MSI', 'Oeanc', 'APP', '+4', 'iphone6plus', ' 利', 'AWM', 'TPP', 'iBoy', 'PS4/NS', 'steam', 'ST', 'Credo', 'VR ', 'TT', 'LPL']
# =======================
# SHI : ['是', '像是']
# =======================
# VE : ['盛贊', '訴說', '披露', '看看', '公認', '抱怨', '認為', '提猜', '示範', '看出', '反對', '提到', '檢測', '預期', '廣播', '查找', '回答', '證明', '申卡', '發誓', '研究', '估值', '形容', '以為', '爆料', '傳聞', '判定', '想', '討說', '精准', '賭約', '想好', '看到', '告訴', '想起', '禁止', '預計', '調研', '談', '公示', '想到', '宣佈', '證', '深思', '假設', '鑒定', '慶祝', '猜', '判罰', '查看', '暗示', '預測', '介紹', '聯想', '發現', '想要', '做到', '稱', '探索', '聽說', '防止', '公告', '講解', '承諾', '回顧', '聽到', '問', '呼', '考慮', '幻想', '感嘆', '要', '准', '探討', '提起', '查', '判斷', '安排', '提', '提醒', '商量', '講', '聽', '自嘲', '知詢', '限制', '報道', '預定', '見', '見證', '算', '設想', '避免', '炫耀', '呼籲', '確認', '警惕', '看清楚', '公佈', '說明']
# =======================
# DE : ['之', '得', '的', '地']
# =======================
# VHC : ['溫暖', '增長', '國際化', '增 ', '結束', '可憐', '機構化', '現代化', '恢復', '暫停', '告破', '豐富', '淡化', '普及', '壞', '智能化', '產生', '降低', '停', '優化', '穩定', '還原', '縮小', '感動', '斷', '下來', '煩', '傷', '肥', '加快', '減少', '愁死', '震驚', '麻煩', '強化', '增強', '破', '陷', '增加', '滿足', '開', '冷卻', '繁榮', '凍', '平衡', '擴張', '辛苦', '愁壞', '公開', '團結', '變動', '規模化', '熱']
# =======================
# Ng : ['內', '般', '以下', '初', '之內', '底', '前', '時', '間', '之中', '之上', '起', '以上', '之後', '之前', '以外', '以來', '中', '為止', '裡', '外', '上', '之外', '之下', '來', '下', '後', '而言', '之間', '左右', '以後']
# =======================
# VK : ['注意', '意外', '需', '欲', '願意', '懂得', '奇怪', '懷疑', '想見', '感謝', '討厭', '曲解', '瞭解', '回憶', '所謂', '需要', '擔心', '不忘', '依賴', '意味', '信', '堅持', '喜歡', '感覺', '遺憾', '顯示', '期待', '知', '希望', '肯定', '害怕', '不滿', '理解', '介意', '遇', '意想不到', '小心', '恐', '放心', '恨', '知道', '忘記', '忘', '明白', '感覺到', '感受', '抱歉', '願', '懂', '確定', '覺得', '怕', '同意', '覺', '盼', '有利於', '流傳', '指望', '面臨']
# =======================
# Ncd : ['兩旁', '西部', '對面', '內', '哪兒', '畔', '哪裡', '以下', '底部', '東部', '中間', '當中', '一帶', '這裡', '外面', '邊', '間', '前沿', '西', '上面', '上方', '旁邊', '哪', '方', '中', '裡', '東', '外', '東方', '哪下', '上', '裡面', '下', '中部', '北', '那邊', '末端', '那裡', '東西部']
# =======================
# A : ['眾', '優質', '業餘', '唯一', '單', '額外', '現行', '歐式', '新興', '同等', '共同', '後置', '主', '多餘', '上上', '野生', '高度', '新一代', '現役', '獨家', '常務', '基礎', '乒乓', '長途', '超級', '大幅度', '國產', '超', '火紅', '最佳', '總', '頭號', '同一', '彩色', '二手', '重磅', '基層', '碧藍', '一般', '真正', '獨門', '中', '前置', '必備', '寶有', '原', '小本', '獨角', '雙', '非', '麻辣', '綜合', '地下', '中西']
# =======================
# V_2 : ['有']
# =======================
# VL : ['開始', '能', '甘願', '後悔', '使得', '愛', '愛好', '便利', '使', '趨於', '讓', '持續', '喜好', '致', '敢', '用來', '肯', '不惜', '令', '習慣', '導致', '故意']
# =======================
# T : ['去', '吧', '來', '哦', '啊', '啦', '嗎', '麼', '哪', '的', '呢', '矣', '了', '嘛', '咯']
# =======================
# VI : ['取勝', '專用', '傾心', '著稱', '驚艷']
# =======================
# DASHCATEGORY : ['-', '—']
# =======================
# I : ['瑪法里奧', '哦']
# =======================
# Dk : ['那', '那麼', '反過來', '據聞', '外傳', '結果', '據說', '想不到']
# =======================
# VF : ['叫', '要求', '止住', '帶領', '試試', '擬', '推選', '圖', '拒', '助', '邀', '停止', '告誡', '催', '打算', '拒絕', '試', '率領', '申請', '勸說', '逼', '判', '繼續', '鼓勵', '準備', '策劃', '勸住', '請']
# =======================
# Da : ['光', '最多', '幾近', '約', '將近', '幾乎', '只', '足足', '近', '唯獨', '共', '正好', '才', '僅', '不下']
# =======================
# PARENTHESISCATEGORY : ['（', '」', '(', '》', '《', '）', '「']
# =======================
# Nv : ['銷售', '組合', '私募', '管理', '抗戰', '推薦', '航海', '分銷', '射擊', '登山', '解救', '度假', '配置', '護髮', '思考', '生產', '買單', '問', '增發', '營銷', '絕殺', '回歸', '開發', '創業', '關聯', '供電', '惡搞', '輔助', '訴訟', '體驗', '兼職', '翻譯', '防治', '錄制', '代理', '遊樂', '燃燒', '研究', '判罰', '疊加', '旅遊', '工作', '經歷', '崩潰', '批發', '灌籃']
# =======================
# PERIODCATEGORY : ['。', '·']
# =======================
# VAC : ['蒸發', '推進', '上演', '集合', '移動', '動']
# =======================
# Dfb : ['極了', '一點', '些']
# =======================
# Cab : ['等等', '等']
# =======================
# SEMICOLONCATEGORY : ['；']
# =======================
# Neqb : ['幾', '以上', '多', '半']
# =======================
# ETCCATEGORY : ['…']
# =======================
# Cba : ['的話']
# =======================
# DOTCATEGORY : ['.']
# =======================

# %% [markdown]
# |         Type        |     Description    |
# |:-------------------:|:------------------:|
# | A                   | 非謂形容詞         |
# | Caa                 | 對等連接詞         |
# | Cab                 | 連接詞，如：等等   |
# | Cba                 | 連接詞，如：的話   |
# | Cbb                 | 關聯連接詞         |
# | D                   | 副詞               |
# | Da                  | 數量副詞           |
# | Dfa                 | 動詞前程度副詞     |
# | Dfb                 | 動詞後程度副詞     |
# | Di                  | 時態標記           |
# | Dk                  | 句副詞             |
# | DM                  | 定量式             |
# | I                   | 感嘆詞             |
# | Na                  | 普通名詞           |
# | Nb                  | 專有名詞           |
# | Nc                  | 地方詞             |
# | Ncd                 | 位置詞             |
# | Nd                  | 時間詞             |
# | Nep                 | 指代定詞           |
# | Neqa                | 數量定詞           |
# | Neqb                | 後置數量定詞       |
# | Nes                 | 特指定詞           |
# | Neu                 | 數詞定詞           |
# | Nf                  | 量詞               |
# | Ng                  | 後置詞             |
# | Nh                  | 代名詞             |
# | Nv                  | 名物化動詞         |
# | P                   | 介詞               |
# | T                   | 語助詞             |
# | VA                  | 動作不及物動詞     |
# | VAC                 | 動作使動動詞       |
# | VB                  | 動作類及物動詞     |
# | VC                  | 動作及物動詞       |
# | VCL                 | 動作接地方賓語動詞 |
# | VD                  | 雙賓動詞           |
# | VF                  | 動作謂賓動詞       |
# | VE                  | 動作句賓動詞       |
# | VG                  | 分類動詞           |
# | VH                  | 狀態不及物動詞     |
# | VHC                 | 狀態使動動詞       |
# | VI                  | 狀態類及物動詞     |
# | VJ                  | 狀態及物動詞       |
# | VK                  | 狀態句賓動詞       |
# | VL                  | 狀態謂賓動詞       |
# | V_2                 | 有                 |
# |                     |                    |
# | DE                  | 的之得地           |
# | SHI                 | 是                 |
# | FW                  | 外文               |
# |                     |                    |
# | COLONCATEGORY       | 冒號               |
# | COMMACATEGORY       | 逗號               |
# | DASHCATEGORY        | 破折號             |
# | DOTCATEGORY         | 點號               |
# | ETCCATEGORY         | 刪節號             |
# | EXCLAMATIONCATEGORY | 驚嘆號             |
# | PARENTHESISCATEGORY | 括號               |
# | PAUSECATEGORY       | 頓號               |
# | PERIODCATEGORY      | 句號               |
# | QUESTIONCATEGORY    | 問號               |
# | SEMICOLONCATEGORY   | 分號               |
# | SPCHANGECATEGORY    | 雙直線             |
# | WHITESPACE          | 空白               |

# %%
def get_bow_vector_with_selection(pairs, word2index):
    excluded_flags = [
        # 根據以上列舉出來的文字以及詞性表，請列出想要排除的詞性
        'Nh', 'Nep', 'Nes', 'DE', 'T', 'P', 'V_2', 'SHI',
        'Dfa', 'Dfb', 'Da', 'Di', 'Dk',
        'Caa', 'Cab', 'Cba', 'Cbb',
        'COLONCATEGORY', 'COMMACATEGORY', 'DASHCATEGORY', 'DOTCATEGORY', 'ETCCATEGORY', 'EXCLAMATIONCATEGORY',
        'PARENTHESISCATEGORY', 'PAUSECATEGORY', 'PERIODCATEGORY', 'QUESTIONCATEGORY', 'SEMICOLONCATEGORY',
        'SPCHANGECATEGORY', 'WHITESPACE'
    ]
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index and flag not in excluded_flags:
            vector[word2index[word]] += 1

    return vector

# %% [markdown]
# # Cosine Similarity

# %%
cosine_similarity = lambda x, y: np.dot(x, y) / (np.linalg.norm(x) * np.linalg.norm(y))

# %%
bow1 = get_bow_vector(train_title_cuts[100], word2index)
bow2 = get_bow_vector(train_title_cuts[130], word2index)
cosine_similarity(bow1, bow2)
# Out:
# 0.08703882797784893

# %%
train_title_cuts[100]
# Out:
# [('山東', 'Nc'),
#  ('魯能', 'Nb'),
#  ('有沒有', 'D'),
#  ('可能', 'D'),
#  ('拿到', 'VC'),
#  ('今年', 'Nd'),
#  ('的', 'DE'),
#  ('中', 'A'),
#  ('超', 'A'),
#  ('冠軍', 'Na'),
#  ('？', 'QUESTIONCATEGORY')]

# %%
train_title_cuts[130]
# Out:
# [('NBA', 'Nb'),
#  ('和', 'Caa'),
#  ('CBA', 'FW'),
#  ('差距', 'Na'),
#  ('在', 'P'),
#  ('哪裡', 'Ncd'),
#  ('？', 'QUESTIONCATEGORY'),
#  ('6', 'Neu'),
#  ('張', 'Nf'),
#  ('圖', 'VF'),
#  ('一目瞭然', 'VH'),
#  ('！', 'EXCLAMATIONCATEGORY')]

# %% [markdown]
# # Group mean vector

# %%
group_vectors = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(train_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    news_class = train_classes[index]
    group_vectors[news_class].append(vector)

group_mean_vector = {}
for news_class, vectors in group_vectors.items():
    group_mean_vector[news_class] = np.mean(vectors, axis=0)
group_mean_vector
# Out:
# {'旅遊': array([0., 0., 0., ..., 0., 0., 0.]),
#  '科技': array([0., 0., 0., ..., 0., 0., 0.]),
#  '財經': array([0., 0., 0., ..., 0., 0., 0.]),
#  '農業': array([0., 0., 0., ..., 0., 0., 0.]),
#  '遊戲': array([0.        , 0.        , 0.        , ..., 0.00333333, 0.00333333,
#         0.00333333]),
#  '體育': array([0.04      , 0.01333333, 0.00333333, ..., 0.        , 0.        ,
#         0.        ])}

# %% [markdown]
# # Group mean vector: 測試

# %%
classification = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(test_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    if np.sum(np.square(vector)) == 0:
        continue

    max_val = -2.0
    max_class = None
    for news_class, ref_vector in group_mean_vector.items():
        val = cosine_similarity(ref_vector, vector)
        if val > max_val:
            max_class = news_class
            max_val = val

    classification[max_class].append(index)

# %%
from collections import Counter

for group, ids in classification.items():
    counter = Counter([test_classes[id] for id in ids])
    print('predict', group, ': ', counter)
# Out:
# predict 體育 :  Counter({'體育': 73, '遊戲': 8, '財經': 6, '旅遊': 6, '農業': 6, '科技': 3})
# predict 財經 :  Counter({'財經': 67, '科技': 18, '體育': 6, '旅遊': 6, '遊戲': 6, '農業': 5})
# predict 科技 :  Counter({'科技': 62, '財經': 13, '體育': 10, '農業': 6, '遊戲': 6, '旅遊': 2})
# predict 旅遊 :  Counter({'旅遊': 70, '農業': 11, '財經': 6, '科技': 3, '遊戲': 2})
# predict 農業 :  Counter({'農業': 70, '旅遊': 9, '科技': 6, '體育': 5, '財經': 4, '遊戲': 3})
# predict 遊戲 :  Counter({'遊戲': 75, '科技': 7, '旅遊': 5, '體育': 4, '財經': 4, '農業': 1})
