# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import nltk
nltk.download('punkt')
import numpy as np
import pandas as pd

dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2356個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index, index_word = {}, {}
for idx, word in enumerate(whole_words):
    word_index[word] = idx
    index_word[idx] = word

# %%
word_index
# Out:
# {'Kabuki': 0,
#  'dirt': 1,
#  'venturing': 2,
#  'Probably': 3,
#  'to': 4,
#  'cheap': 5,
#  'avocado': 6,
#  'delivery': 7,
#  'goat': 8,
#  'gem': 9,
#  'MUST': 10,
#  '1979': 11,
#  'milkshake': 12,
#  'professional': 13,
#  'packed': 14,
#  'pastas': 15,
#  'andddd': 16,
#  'ALL': 17,
#  'Fridays': 18,
#  'Bussell': 19,
#  'Favorite': 20,
#  'crumby': 21,
#  'looking': 22,
#  'put': 23,
#  'martini': 24,
#  'FREEZING': 25,
#  'falafels': 26,
#  'reasons': 27,
#  'guest': 28,
#  'anything': 29,
#  'Overpriced': 30,
#  'Mediocre': 31,
#  'asked': 32,
#  'gold': 33,
#  'daughter': 34,
#  'Talk': 35,
#  'saffron': 36,
#  'impressed': 37,
#  'multi-grain': 38,
#  'sewer': 39,
#  'late': 40,
#  'fabulous': 41,
#  'book': 42,
#  'fill': 43,
#  'chow': 44,
#  'Flower': 45,
#  'above': 46,
#  'Jeff': 47,
#  'son': 48,
#  'grilled': 49,
#  'section': 50,
#  'short': 51,
#  'each': 52,
#  ')': 53,
#  'needed': 54,
#  'glance': 55,
#  'employee': 56,
#  'shrimp': 57,
#  'included': 58,
#  'someone': 59,
#  'limited': 60,
#  'tasty': 61,
#  'because': 62,
#  'hit': 63,
#  'frozen': 64,
#  'underwhelming': 65,
#  'specials': 66,
#  'difference': 67,
#  'Went': 68,
#  'done': 69,
#  'leather': 70,
#  'Eggplant': 71,
#  'job': 72,
#  'My': 73,
#  'generic': 74,
#  'wings': 75,
#  'mixed': 76,
#  'particular': 77,
#  'Once': 78,
#  'saying': 79,
#  'services': 80,
#  'hostess': 81,
#  'area': 82,
#  'lovely': 83,
#  'touched': 84,
#  'close': 85,
#  'parents': 86,
#  'another': 87,
#  'watch': 88,
#  'TOLD': 89,
#  'golden-crispy': 90,
#  'douchey': 91,
#  'T.': 92,
#  'inside': 93,
#  'biscuits': 94,
#  'said': 95,
#  'verge': 96,
#  'courteous': 97,
#  'prompt': 98,
#  'Point': 99,
#  'par': 100,
#  'honor': 101,
#  'fresh': 102,
#  'combos': 103,
#  '40min': 104,
#  'none': 105,
#  'double': 106,
#  'business': 107,
#  '15': 108,
#  'over': 109,
#  'poured': 110,
#  'As': 111,
#  'appalling': 112,
#  'Soggy': 113,
#  'anticipated': 114,
#  'Salads': 115,
#  'were': 116,
#  'delightful': 117,
#  'bug': 118,
#  'Before': 119,
#  'public': 120,
#  'Penne': 121,
#  'Paying': 122,
#  'serve': 123,
#  'lovers': 124,
#  'arrives': 125,
#  'Things': 126,
#  'attached': 127,
#  'plain': 128,
#  'Ordered': 129,
#  'Waitress': 130,
#  'High-quality': 131,
#  'other': 132,
#  'Awful': 133,
#  'LOVED': 134,
#  'STEP': 135,
#  'crisp': 136,
#  'table': 137,
#  'interesting': 138,
#  'Sooooo': 139,
#  'Kind': 140,
#  'make': 141,
#  'especially': 142,
#  'giving': 143,
#  'there': 144,
#  'house': 145,
#  'AZ': 146,
#  'fail': 147,
#  'hurry': 148,
#  'Blah': 149,
#  'sliced': 150,
#  'besides': 151,
#  'space': 152,
#  'Frozen': 153,
#  'girlfriend': 154,
#  'fat': 155,
#  '4': 156,
#  'From': 157,
#  'VERY': 158,
#  'Generous': 159,
#  '*': 160,
#  'rave': 161,
#  'Omelets': 162,
#  'Crostini': 163,
#  'pink': 164,
#  'Over': 165,
#  'tuna': 166,
#  'Dessert': 167,
#  'note': 168,
#  'Gordon': 169,
#  'hummus': 170,
#  'Just': 171,
#  'dry': 172,
#  'Lordy': 173,
#  'ala': 174,
#  'coming': 175,
#  'mushrooms': 176,
#  'held': 177,
#  'these': 178,
#  'offered': 179,
#  'non-fancy': 180,
#  'ambience': 181,
#  'including': 182,
#  'lacking': 183,
#  'Sat': 184,
#  'wonderful': 185,
#  'clue': 186,
#  'dining': 187,
#  'modern': 188,
#  'months': 189,
#  'due': 190,
#  '10+': 191,
#  'fun': 192,
#  'just': 193,
#  'etc': 194,
#  'peanut': 195,
#  'guess': 196,
#  'Mango': 197,
#  'bad': 198,
#  'melt': 199,
#  'profiterole': 200,
#  'happened': 201,
#  'known': 202,
#  'hospitality': 203,
#  'always': 204,
#  'can': 205,
#  'longer': 206,
#  'madhouse': 207,
#  'ladies': 208,
#  'shall': 209,
#  'hands-down': 210,
#  'mesquite': 211,
#  'rarely': 212,
#  'Pros': 213,
#  'kids': 214,
#  'Not': 215,
#  'atrocious': 216,
#  'Wife': 217,
#  'lacked': 218,
#  'swung': 219,
#  'second': 220,
#  'Wo': 221,
#  'such': 222,
#  'brings': 223,
#  'Waiter': 224,
#  'boys': 225,
#  'sashimi': 226,
#  'ok': 227,
#  'sub-par': 228,
#  'circumstances': 229,
#  'appetizer': 230,
#  'relax': 231,
#  'kitchen': 232,
#  'whatsoever': 233,
#  "ya'all": 234,
#  'out': 235,
#  'glad': 236,
#  'mussels': 237,
#  'boxes': 238,
#  'cream': 239,
#  'Delicious': 240,
#  'It': 241,
#  'fella': 242,
#  'before': 243,
#  'surprised': 244,
#  'combo': 245,
#  'onion': 246,
#  'relleno': 247,
#  'lack': 248,
#  'definately': 249,
#  'clean': 250,
#  'street': 251,
#  '1.5lb': 252,
#  'AND': 253,
#  'familiar': 254,
#  'lady': 255,
#  'Go': 256,
#  'charge': 257,
#  'delicious': 258,
#  'me': 259,
#  'papers': 260,
#  'really': 261,
#  'Christmas': 262,
#  'chocolate': 263,
#  'sick': 264,
#  'opposed': 265,
#  'Otto': 266,
#  'sauces': 267,
#  'management': 268,
#  'sexy': 269,
#  'tender': 270,
#  'Every': 271,
#  'Hard': 272,
#  'turn': 273,
#  'flop': 274,
#  'Although': 275,
#  'name': 276,
#  'cocktail': 277,
#  'should': 278,
#  'impressive': 279,
#  'hopes': 280,
#  'absolutely': 281,
#  'solidify': 282,
#  'under-services': 283,
#  'deserves': 284,
#  'order': 285,
#  "'m": 286,
#  'wife': 287,
#  'fast': 288,
#  'when': 289,
#  'an': 290,
#  'years': 291,
#  'Avoid': 292,
#  'Mirage': 293,
#  'topic': 294,
#  'coconut': 295,
#  'fondue': 296,
#  'joint': 297,
#  'wrong': 298,
#  'drink': 299,
#  'sunglasses': 300,
#  'hour': 301,
#  'ask': 302,
#  'yucky': 303,
#  'average': 304,
#  'imagination': 305,
#  'OWNERS': 306,
#  'Give': 307,
#  'Do': 308,
#  'tea': 309,
#  'cooked': 310,
#  'bucks': 311,
#  'dedicated': 312,
#  'Camelback': 313,
#  'wait': 314,
#  'closed': 315,
#  'dine': 316,
#  'movies': 317,
#  'ensued': 318,
#  'A': 319,
#  'pears': 320,
#  'Bean': 321,
#  'pepper': 322,
#  'Phoenix': 323,
#  'hip': 324,
#  '/hand': 325,
#  'others': 326,
#  'typical': 327,
#  'kid': 328,
#  'come': 329,
#  'filling': 330,
#  'experiencing': 331,
#  'instead': 332,
#  'BLAND': 333,
#  'gone': 334,
#  'Sun': 335,
#  'no': 336,
#  'reading': 337,
#  'single': 338,
#  'reminds': 339,
#  'Mushroom': 340,
#  'plastic': 341,
#  'received': 342,
#  'deeply': 343,
#  'trippy': 344,
#  'wildly': 345,
#  'realized': 346,
#  'Baba': 347,
#  'hereas': 348,
#  'tartare': 349,
#  'Needless': 350,
#  'server': 351,
#  'outta': 352,
#  'satifying': 353,
#  'steakhouse': 354,
#  'AGAIN': 355,
#  'i': 356,
#  '23': 357,
#  'nude': 358,
#  'sushi': 359,
#  'batch': 360,
#  'banana': 361,
#  'dinners': 362,
#  'selections': 363,
#  'ordered': 364,
#  'flavourful': 365,
#  'front': 366,
#  'WAAAAAAyyyyyyyyyy': 367,
#  'experienced': 368,
#  'fluffy': 369,
#  'Disappointed': 370,
#  'portions': 371,
#  'Terrible': 372,
#  'mistake': 373,
#  'fruit': 374,
#  'pita': 375,
#  'polite': 376,
#  'outrageously': 377,
#  'ethic': 378,
#  'waiting': 379,
#  'rude': 380,
#  'honest': 381,
#  'stars': 382,
#  'arriving': 383,
#  'flirting': 384,
#  'paper': 385,
#  "n't": 386,
#  'greasy': 387,
#  'accommodations': 388,
#  'article': 389,
#  'spaghetti': 390,
#  'feeling': 391,
#  'talk': 392,
#  'thin': 393,
#  '20': 394,
#  'play': 395,
#  'imaginative': 396,
#  'version': 397,
#  'found': 398,
#  'IN': 399,
#  'attack': 400,
#  'hair': 401,
#  'potato': 402,
#  'breaks': 403,
#  'Dylan': 404,
#  'expert/connisseur': 405,
#  'San': 406,
#  'later': 407,
#  'bit': 408,
#  'worst': 409,
#  'cant': 410,
#  'proven': 411,
#  'marrow': 412,
#  'staying': 413,
#  'nothing': 414,
#  'dude': 415,
#  'NOT': 416,
#  'Cibo': 417,
#  'downside': 418,
#  'Then': 419,
#  'eggplant': 420,
#  'works': 421,
#  'smells': 422,
#  'insanely': 423,
#  'chefs': 424,
#  'pucks': 425,
#  'pine': 426,
#  'same': 427,
#  'Philadelphia': 428,
#  '.': 429,
#  'Lastly': 430,
#  'literally': 431,
#  'cannoli': 432,
#  'forever': 433,
#  'first': 434,
#  'expectations': 435,
#  'mind': 436,
#  'meatloaf': 437,
#  'No': 438,
#  'serves': 439,
#  'atmosphere.1': 440,
#  'added': 441,
#  'with': 442,
#  "'ll": 443,
#  'Weird': 444,
#  'uninspired': 445,
#  'salt': 446,
#  'suffers': 447,
#  'plus': 448,
#  'yet': 449,
#  'Always': 450,
#  'approval': 451,
#  'amazing': 452,
#  'hits': 453,
#  'charming': 454,
#  'going': 455,
#  'though': 456,
#  'seasonal': 457,
#  'understand': 458,
#  'smoke': 459,
#  'choose': 460,
#  'in': 461,
#  'which': 462,
#  'egg': 463,
#  'word': 464,
#  'thinly': 465,
#  'negligent': 466,
#  'chains': 467,
#  'rated': 468,
#  'than': 469,
#  'Tasted': 470,
#  'coupons': 471,
#  'transcendant': 472,
#  'Large': 473,
#  'metro': 474,
#  'common': 475,
#  'review': 476,
#  'located': 477,
#  'yukon': 478,
#  'big': 479,
#  'Awesome': 480,
#  'needs': 481,
#  'Really': 482,
#  'carbs': 483,
#  'experience': 484,
#  'sub': 485,
#  '``': 486,
#  'enjoyed': 487,
#  'wines': 488,
#  'forty': 489,
#  'Cute': 490,
#  'anymore': 491,
#  'Maybe': 492,
#  'dirty': 493,
#  'Cape': 494,
#  'empty': 495,
#  'BEST': 496,
#  'bars': 497,
#  'human': 498,
#  'cute': 499,
#  'party': 500,
#  'donut': 501,
#  'stir': 502,
#  'hot': 503,
#  'theft': 504,
#  'blow': 505,
#  'touch': 506,
#  'quit': 507,
#  'hooked': 508,
#  'overcooked': 509,
#  'Perfect': 510,
#  'Last': 511,
#  'prepared': 512,
#  'truly': 513,
#  'First': 514,
#  'styrofoam': 515,
#  'Firehouse': 516,
#  'waiter': 517,
#  'Never': 518,
#  'I': 519,
#  'pats': 520,
#  'strawberry': 521,
#  'hankering': 522,
#  'power': 523,
#  'cheese': 524,
#  'Magazine': 525,
#  'accordingly': 526,
#  'Bar': 527,
#  'beautiful': 528,
#  'refried': 529,
#  'highlighted': 530,
#  'informative': 531,
#  'barely': 532,
#  'BBQ': 533,
#  'condiment': 534,
#  'satisfied': 535,
#  'godfathers': 536,
#  '%': 537,
#  'To': 538,
#  'tummy': 539,
#  'Sushi': 540,
#  'Horrible': 541,
#  'tapas': 542,
#  'Tried': 543,
#  'HAD': 544,
#  'took': 545,
#  'Classy/warm': 546,
#  'drastically': 547,
#  'pork': 548,
#  'bakery': 549,
#  'Brushfire': 550,
#  'whether': 551,
#  'Friend': 552,
#  'crêpe': 553,
#  'Strike': 554,
#  'claimed': 555,
#  'Based': 556,
#  'refrained': 557,
#  'Mandalay': 558,
#  'Try': 559,
#  'vodka': 560,
#  'getting': 561,
#  'unprofessional': 562,
#  'setting': 563,
#  'Pineapple': 564,
#  'She': 565,
#  'thru': 566,
#  'lukewarm': 567,
#  'OVERPRICED': 568,
#  'few': 569,
#  'Luke': 570,
#  'taco': 571,
#  'least': 572,
#  'must': 573,
#  'very': 574,
#  'sides': 575,
#  'cafe': 576,
#  'waited': 577,
#  'Join': 578,
#  'Took': 579,
#  'coffee': 580,
#  'favor': 581,
#  '..there': 582,
#  'shirt': 583,
#  'loved': 584,
#  'salads': 585,
#  'At': 586,
#  'family': 587,
#  'piece': 588,
#  'crusty': 589,
#  'reviews': 590,
#  'OMG': 591,
#  'Eclectic': 592,
#  'dates': 593,
#  'meats': 594,
#  'Filet': 595,
#  'properly': 596,
#  'Greek': 597,
#  'left': 598,
#  'value': 599,
#  'every': 600,
#  'recently': 601,
#  'bottom': 602,
#  'rings': 603,
#  'NONE': 604,
#  'WHAT': 605,
#  'otherwise': 606,
#  'Highly': 607,
#  'fear': 608,
#  'Any': 609,
#  'style': 610,
#  'walls': 611,
#  'spice': 612,
#  'probably': 613,
#  'tailored': 614,
#  'flavor': 615,
#  'boyfriend': 616,
#  'largely': 617,
#  'GREAT': 618,
#  'vain': 619,
#  'creamy': 620,
#  'Thoroughly': 621,
#  'dish': 622,
#  'dessert': 623,
#  '10': 624,
#  'teeth': 625,
#  '&': 626,
#  '4.00': 627,
#  'looks': 628,
#  'sangria': 629,
#  'Are': 630,
#  'liked': 631,
#  'rolls': 632,
#  'how': 633,
#  'juries': 634,
#  'Denny': 635,
#  'Macarons': 636,
#  'WASTE': 637,
#  'medium': 638,
#  'leave': 639,
#  'excellent': 640,
#  'kind': 641,
#  'capers': 642,
#  'thick': 643,
#  'mood': 644,
#  'complaints': 645,
#  'pop': 646,
#  ',': 647,
#  'cashier': 648,
#  'disaster': 649,
#  'CONCLUSION': 650,
#  'tacos': 651,
#  'Las': 652,
#  'MANY': 653,
#  'veal': 654,
#  'degree': 655,
#  'strangers': 656,
#  'whole': 657,
#  'register': 658,
#  'rinse': 659,
#  'those': 660,
#  'Will': 661,
#  'gratitude': 662,
#  'outshining': 663,
#  'vegan/veggie': 664,
#  'from': 665,
#  'drenched': 666,
#  'huevos': 667,
#  'Joey': 668,
#  'Ninja': 669,
#  'likes': 670,
#  'sound': 671,
#  'sign': 672,
#  'BETTER': 673,
#  'relocated': 674,
#  'Extremely': 675,
#  'tater': 676,
#  'unbelievable': 677,
#  'different': 678,
#  'downtown': 679,
#  'constructed': 680,
#  'gristle': 681,
#  'Bisque': 682,
#  'Han': 683,
#  'opinion': 684,
#  'spotty': 685,
#  'boiled': 686,
#  'fellow': 687,
#  'unexperienced': 688,
#  'recommendation': 689,
#  'finally': 690,
#  'point': 691,
#  'beers': 692,
#  'pneumatic': 693,
#  'affordable': 694,
#  'mac': 695,
#  'returning': 696,
#  'Total': 697,
#  'Heart': 698,
#  'angry': 699,
#  'sergeant': 700,
#  'his': 701,
#  'blame': 702,
#  'dirty-': 703,
#  'call': 704,
#  'funny': 705,
#  'imagine': 706,
#  'weekend': 707,
#  '?': 708,
#  'rest': 709,
#  'EXPERIENCE': 710,
#  'seems': 711,
#  'shopping': 712,
#  'colder': 713,
#  'bowl': 714,
#  'served': 715,
#  'dark': 716,
#  'fo': 717,
#  'bodes': 718,
#  'OK': 719,
#  'awful': 720,
#  'pumpkin': 721,
#  'promptly': 722,
#  'milk': 723,
#  'pictures': 724,
#  'vibe': 725,
#  'sause': 726,
#  'meet': 727,
#  'easily': 728,
#  'consider': 729,
#  'NYC': 730,
#  'best': 731,
#  'must-stop': 732,
#  'Everyone': 733,
#  'Aria': 734,
#  'stood': 735,
#  'driest': 736,
#  'redeeming': 737,
#  'Left': 738,
#  'ate': 739,
#  'Service': 740,
#  'Hot': 741,
#  'Phenomenal': 742,
#  'round': 743,
#  'overall': 744,
#  'perpared': 745,
#  'today': 746,
#  'for': 747,
#  'fireball': 748,
#  'descriptions': 749,
#  'friends': 750,
#  'greens': 751,
#  'hardly': 752,
#  'lighter': 753,
#  'on': 754,
#  'Check': 755,
#  'In': 756,
#  'homemade': 757,
#  'awesome': 758,
#  'reasonable': 759,
#  'sat': 760,
#  'Pretty': 761,
#  'was': 762,
#  'patty': 763,
#  'bye': 764,
#  'profound': 765,
#  'like': 766,
#  'recommended': 767,
#  '6': 768,
#  'completely': 769,
#  'disgraceful': 770,
#  'selection': 771,
#  'Experience': 772,
#  'cheesecurds': 773,
#  'wire': 774,
#  'nice': 775,
#  'puréed': 776,
#  'stretch': 777,
#  'Coming': 778,
#  'handled': 779,
#  'soup': 780,
#  'spot': 781,
#  'smelled': 782,
#  'that': 783,
#  'Insults': 784,
#  '!': 785,
#  'pay': 786,
#  'middle': 787,
#  'fails': 788,
#  'crawfish': 789,
#  'If': 790,
#  'get': 791,
#  'covers': 792,
#  'ended': 793,
#  'do': 794,
#  '2007': 795,
#  'happier': 796,
#  'breakfast': 797,
#  'bigger': 798,
#  'awkward': 799,
#  'wall': 800,
#  'white': 801,
#  'falling': 802,
#  'ball': 803,
#  'burgers': 804,
#  'company': 805,
#  'unique': 806,
#  'cashew': 807,
#  'perfection': 808,
#  'relationship': 809,
#  'flat': 810,
#  'disgrace': 811,
#  'Prices': 812,
#  'sals': 813,
#  'OF': 814,
#  'velvet': 815,
#  'customers': 816,
#  'heart': 817,
#  'considering': 818,
#  'Ample': 819,
#  'thumbs': 820,
#  'fucking': 821,
#  'correct': 822,
#  'Gourmet': 823,
#  'poorly': 824,
#  'Disappointing': 825,
#  'most': 826,
#  'disapppointment': 827,
#  '...': 828,
#  'hardest': 829,
#  'soundtrack': 830,
#  'guacamole': 831,
#  'pissd': 832,
#  'Hunan': 833,
#  'maintaining': 834,
#  'eel': 835,
#  'sucks': 836,
#  'Attack': 837,
#  'pleasure': 838,
#  '*heart*': 839,
#  'store': 840,
#  'uploaded': 841,
#  'head': 842,
#  'course': 843,
#  'year': 844,
#  'gloves.Everything': 845,
#  'Francisco': 846,
#  'pleasant': 847,
#  'Same': 848,
#  'although': 849,
#  'surprise': 850,
#  'Please': 851,
#  'extraordinary': 852,
#  'yay': 853,
#  'cause': 854,
#  'TOTAL': 855,
#  'menu/': 856,
#  'deal': 857,
#  '90': 858,
#  'stop': 859,
#  'describing': 860,
#  'Seriously': 861,
#  'Mellow': 862,
#  'reservation': 863,
#  'apologize': 864,
#  'similar': 865,
#  'craving': 866,
#  'slow': 867,
#  '.very': 868,
#  'sharply': 869,
#  'rancheros': 870,
#  'night': 871,
#  'Crust': 872,
#  'walked': 873,
#  'supposed': 874,
#  'soooo': 875,
#  'grab': 876,
#  'tenders': 877,
#  'ventilation': 878,
#  'boy': 879,
#  'lunch': 880,
#  'Best': 881,
#  'showed': 882,
#  'recall': 883,
#  'May': 884,
#  'at': 885,
#  'sense': 886,
#  'STALE': 887,
#  'Bloody': 888,
#  'Caballero': 889,
#  'chickens': 890,
#  'friend': 891,
#  'struggle': 892,
#  'sorely': 893,
#  'thanks': 894,
#  'mein': 895,
#  'concept': 896,
#  'beans': 897,
#  '.the': 898,
#  'occasions': 899,
#  'roasted': 900,
#  'Come': 901,
#  'several': 902,
#  'number': 903,
#  'saganaki': 904,
#  'Yelpers': 905,
#  'INCONSIDERATE': 906,
#  'she': 907,
#  'once': 908,
#  'Hawaiian': 909,
#  'recommend': 910,
#  'When': 911,
#  'Third': 912,
#  'binge': 913,
#  'chewy': 914,
#  'pancakes': 915,
#  'their': 916,
#  'remember': 917,
#  'Buffet': 918,
#  'Unfortunately': 919,
#  'Green': 920,
#  'reviewer': 921,
#  'tell': 922,
#  'edible': 923,
#  'leftover': 924,
#  'still': 925,
#  'came': 926,
#  'pizzas': 927,
#  'pub': 928,
#  'Noca': 929,
#  'accident': 930,
#  '70+': 931,
#  'Steak': 932,
#  'tiny': 933,
#  'baby': 934,
#  'neither': 935,
#  'Yeah': 936,
#  'burned': 937,
#  'everyone': 938,
#  'Toast': 939,
#  'ribeye': 940,
#  'red': 941,
#  'mom': 942,
#  'Google': 943,
#  'boba': 944,
#  'acknowledged': 945,
#  'zero': 946,
#  'presentation': 947,
#  'enough..': 948,
#  'quite': 949,
#  'frustrated': 950,
#  'peanuts': 951,
#  'gotten': 952,
#  'ratio': 953,
#  'places': 954,
#  'box': 955,
#  'nicest': 956,
#  '30': 957,
#  'killer': 958,
#  'SHOULD': 959,
#  'Vegas': 960,
#  'missing': 961,
#  'privileged': 962,
#  'bathrooms': 963,
#  'desired': 964,
#  'less': 965,
#  'relaxed': 966,
#  'usual': 967,
#  'blows': 968,
#  'Gringos': 969,
#  'Khao': 970,
#  'off': 971,
#  'concern': 972,
#  'Sunday': 973,
#  'light': 974,
#  'me..Bunch': 975,
#  'airport': 976,
#  'our': 977,
#  'vinaigrette': 978,
#  'actual': 979,
#  'sit-down': 980,
#  'strip': 981,
#  'silently': 982,
#  'fiancé': 983,
#  'blown': 984,
#  'combination': 985,
#  'batter': 986,
#  'Steiners': 987,
#  'via': 988,
#  'say': 989,
#  'Very': 990,
#  'dead': 991,
#  "'re": 992,
#  'and': 993,
#  'you': 994,
#  'summary': 995,
#  'opened': 996,
#  'Egg': 997,
#  'wanted': 998,
#  'lots': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'Kabuki',
#  1: 'dirt',
#  2: 'venturing',
#  3: 'Probably',
#  4: 'to',
#  5: 'cheap',
#  6: 'avocado',
#  7: 'delivery',
#  8: 'goat',
#  9: 'gem',
#  10: 'MUST',
#  11: '1979',
#  12: 'milkshake',
#  13: 'professional',
#  14: 'packed',
#  15: 'pastas',
#  16: 'andddd',
#  17: 'ALL',
#  18: 'Fridays',
#  19: 'Bussell',
#  20: 'Favorite',
#  21: 'crumby',
#  22: 'looking',
#  23: 'put',
#  24: 'martini',
#  25: 'FREEZING',
#  26: 'falafels',
#  27: 'reasons',
#  28: 'guest',
#  29: 'anything',
#  30: 'Overpriced',
#  31: 'Mediocre',
#  32: 'asked',
#  33: 'gold',
#  34: 'daughter',
#  35: 'Talk',
#  36: 'saffron',
#  37: 'impressed',
#  38: 'multi-grain',
#  39: 'sewer',
#  40: 'late',
#  41: 'fabulous',
#  42: 'book',
#  43: 'fill',
#  44: 'chow',
#  45: 'Flower',
#  46: 'above',
#  47: 'Jeff',
#  48: 'son',
#  49: 'grilled',
#  50: 'section',
#  51: 'short',
#  52: 'each',
#  53: ')',
#  54: 'needed',
#  55: 'glance',
#  56: 'employee',
#  57: 'shrimp',
#  58: 'included',
#  59: 'someone',
#  60: 'limited',
#  61: 'tasty',
#  62: 'because',
#  63: 'hit',
#  64: 'frozen',
#  65: 'underwhelming',
#  66: 'specials',
#  67: 'difference',
#  68: 'Went',
#  69: 'done',
#  70: 'leather',
#  71: 'Eggplant',
#  72: 'job',
#  73: 'My',
#  74: 'generic',
#  75: 'wings',
#  76: 'mixed',
#  77: 'particular',
#  78: 'Once',
#  79: 'saying',
#  80: 'services',
#  81: 'hostess',
#  82: 'area',
#  83: 'lovely',
#  84: 'touched',
#  85: 'close',
#  86: 'parents',
#  87: 'another',
#  88: 'watch',
#  89: 'TOLD',
#  90: 'golden-crispy',
#  91: 'douchey',
#  92: 'T.',
#  93: 'inside',
#  94: 'biscuits',
#  95: 'said',
#  96: 'verge',
#  97: 'courteous',
#  98: 'prompt',
#  99: 'Point',
#  100: 'par',
#  101: 'honor',
#  102: 'fresh',
#  103: 'combos',
#  104: '40min',
#  105: 'none',
#  106: 'double',
#  107: 'business',
#  108: '15',
#  109: 'over',
#  110: 'poured',
#  111: 'As',
#  112: 'appalling',
#  113: 'Soggy',
#  114: 'anticipated',
#  115: 'Salads',
#  116: 'were',
#  117: 'delightful',
#  118: 'bug',
#  119: 'Before',
#  120: 'public',
#  121: 'Penne',
#  122: 'Paying',
#  123: 'serve',
#  124: 'lovers',
#  125: 'arrives',
#  126: 'Things',
#  127: 'attached',
#  128: 'plain',
#  129: 'Ordered',
#  130: 'Waitress',
#  131: 'High-quality',
#  132: 'other',
#  133: 'Awful',
#  134: 'LOVED',
#  135: 'STEP',
#  136: 'crisp',
#  137: 'table',
#  138: 'interesting',
#  139: 'Sooooo',
#  140: 'Kind',
#  141: 'make',
#  142: 'especially',
#  143: 'giving',
#  144: 'there',
#  145: 'house',
#  146: 'AZ',
#  147: 'fail',
#  148: 'hurry',
#  149: 'Blah',
#  150: 'sliced',
#  151: 'besides',
#  152: 'space',
#  153: 'Frozen',
#  154: 'girlfriend',
#  155: 'fat',
#  156: '4',
#  157: 'From',
#  158: 'VERY',
#  159: 'Generous',
#  160: '*',
#  161: 'rave',
#  162: 'Omelets',
#  163: 'Crostini',
#  164: 'pink',
#  165: 'Over',
#  166: 'tuna',
#  167: 'Dessert',
#  168: 'note',
#  169: 'Gordon',
#  170: 'hummus',
#  171: 'Just',
#  172: 'dry',
#  173: 'Lordy',
#  174: 'ala',
#  175: 'coming',
#  176: 'mushrooms',
#  177: 'held',
#  178: 'these',
#  179: 'offered',
#  180: 'non-fancy',
#  181: 'ambience',
#  182: 'including',
#  183: 'lacking',
#  184: 'Sat',
#  185: 'wonderful',
#  186: 'clue',
#  187: 'dining',
#  188: 'modern',
#  189: 'months',
#  190: 'due',
#  191: '10+',
#  192: 'fun',
#  193: 'just',
#  194: 'etc',
#  195: 'peanut',
#  196: 'guess',
#  197: 'Mango',
#  198: 'bad',
#  199: 'melt',
#  200: 'profiterole',
#  201: 'happened',
#  202: 'known',
#  203: 'hospitality',
#  204: 'always',
#  205: 'can',
#  206: 'longer',
#  207: 'madhouse',
#  208: 'ladies',
#  209: 'shall',
#  210: 'hands-down',
#  211: 'mesquite',
#  212: 'rarely',
#  213: 'Pros',
#  214: 'kids',
#  215: 'Not',
#  216: 'atrocious',
#  217: 'Wife',
#  218: 'lacked',
#  219: 'swung',
#  220: 'second',
#  221: 'Wo',
#  222: 'such',
#  223: 'brings',
#  224: 'Waiter',
#  225: 'boys',
#  226: 'sashimi',
#  227: 'ok',
#  228: 'sub-par',
#  229: 'circumstances',
#  230: 'appetizer',
#  231: 'relax',
#  232: 'kitchen',
#  233: 'whatsoever',
#  234: "ya'all",
#  235: 'out',
#  236: 'glad',
#  237: 'mussels',
#  238: 'boxes',
#  239: 'cream',
#  240: 'Delicious',
#  241: 'It',
#  242: 'fella',
#  243: 'before',
#  244: 'surprised',
#  245: 'combo',
#  246: 'onion',
#  247: 'relleno',
#  248: 'lack',
#  249: 'definately',
#  250: 'clean',
#  251: 'street',
#  252: '1.5lb',
#  253: 'AND',
#  254: 'familiar',
#  255: 'lady',
#  256: 'Go',
#  257: 'charge',
#  258: 'delicious',
#  259: 'me',
#  260: 'papers',
#  261: 'really',
#  262: 'Christmas',
#  263: 'chocolate',
#  264: 'sick',
#  265: 'opposed',
#  266: 'Otto',
#  267: 'sauces',
#  268: 'management',
#  269: 'sexy',
#  270: 'tender',
#  271: 'Every',
#  272: 'Hard',
#  273: 'turn',
#  274: 'flop',
#  275: 'Although',
#  276: 'name',
#  277: 'cocktail',
#  278: 'should',
#  279: 'impressive',
#  280: 'hopes',
#  281: 'absolutely',
#  282: 'solidify',
#  283: 'under-services',
#  284: 'deserves',
#  285: 'order',
#  286: "'m",
#  287: 'wife',
#  288: 'fast',
#  289: 'when',
#  290: 'an',
#  291: 'years',
#  292: 'Avoid',
#  293: 'Mirage',
#  294: 'topic',
#  295: 'coconut',
#  296: 'fondue',
#  297: 'joint',
#  298: 'wrong',
#  299: 'drink',
#  300: 'sunglasses',
#  301: 'hour',
#  302: 'ask',
#  303: 'yucky',
#  304: 'average',
#  305: 'imagination',
#  306: 'OWNERS',
#  307: 'Give',
#  308: 'Do',
#  309: 'tea',
#  310: 'cooked',
#  311: 'bucks',
#  312: 'dedicated',
#  313: 'Camelback',
#  314: 'wait',
#  315: 'closed',
#  316: 'dine',
#  317: 'movies',
#  318: 'ensued',
#  319: 'A',
#  320: 'pears',
#  321: 'Bean',
#  322: 'pepper',
#  323: 'Phoenix',
#  324: 'hip',
#  325: '/hand',
#  326: 'others',
#  327: 'typical',
#  328: 'kid',
#  329: 'come',
#  330: 'filling',
#  331: 'experiencing',
#  332: 'instead',
#  333: 'BLAND',
#  334: 'gone',
#  335: 'Sun',
#  336: 'no',
#  337: 'reading',
#  338: 'single',
#  339: 'reminds',
#  340: 'Mushroom',
#  341: 'plastic',
#  342: 'received',
#  343: 'deeply',
#  344: 'trippy',
#  345: 'wildly',
#  346: 'realized',
#  347: 'Baba',
#  348: 'hereas',
#  349: 'tartare',
#  350: 'Needless',
#  351: 'server',
#  352: 'outta',
#  353: 'satifying',
#  354: 'steakhouse',
#  355: 'AGAIN',
#  356: 'i',
#  357: '23',
#  358: 'nude',
#  359: 'sushi',
#  360: 'batch',
#  361: 'banana',
#  362: 'dinners',
#  363: 'selections',
#  364: 'ordered',
#  365: 'flavourful',
#  366: 'front',
#  367: 'WAAAAAAyyyyyyyyyy',
#  368: 'experienced',
#  369: 'fluffy',
#  370: 'Disappointed',
#  371: 'portions',
#  372: 'Terrible',
#  373: 'mistake',
#  374: 'fruit',
#  375: 'pita',
#  376: 'polite',
#  377: 'outrageously',
#  378: 'ethic',
#  379: 'waiting',
#  380: 'rude',
#  381: 'honest',
#  382: 'stars',
#  383: 'arriving',
#  384: 'flirting',
#  385: 'paper',
#  386: "n't",
#  387: 'greasy',
#  388: 'accommodations',
#  389: 'article',
#  390: 'spaghetti',
#  391: 'feeling',
#  392: 'talk',
#  393: 'thin',
#  394: '20',
#  395: 'play',
#  396: 'imaginative',
#  397: 'version',
#  398: 'found',
#  399: 'IN',
#  400: 'attack',
#  401: 'hair',
#  402: 'potato',
#  403: 'breaks',
#  404: 'Dylan',
#  405: 'expert/connisseur',
#  406: 'San',
#  407: 'later',
#  408: 'bit',
#  409: 'worst',
#  410: 'cant',
#  411: 'proven',
#  412: 'marrow',
#  413: 'staying',
#  414: 'nothing',
#  415: 'dude',
#  416: 'NOT',
#  417: 'Cibo',
#  418: 'downside',
#  419: 'Then',
#  420: 'eggplant',
#  421: 'works',
#  422: 'smells',
#  423: 'insanely',
#  424: 'chefs',
#  425: 'pucks',
#  426: 'pine',
#  427: 'same',
#  428: 'Philadelphia',
#  429: '.',
#  430: 'Lastly',
#  431: 'literally',
#  432: 'cannoli',
#  433: 'forever',
#  434: 'first',
#  435: 'expectations',
#  436: 'mind',
#  437: 'meatloaf',
#  438: 'No',
#  439: 'serves',
#  440: 'atmosphere.1',
#  441: 'added',
#  442: 'with',
#  443: "'ll",
#  444: 'Weird',
#  445: 'uninspired',
#  446: 'salt',
#  447: 'suffers',
#  448: 'plus',
#  449: 'yet',
#  450: 'Always',
#  451: 'approval',
#  452: 'amazing',
#  453: 'hits',
#  454: 'charming',
#  455: 'going',
#  456: 'though',
#  457: 'seasonal',
#  458: 'understand',
#  459: 'smoke',
#  460: 'choose',
#  461: 'in',
#  462: 'which',
#  463: 'egg',
#  464: 'word',
#  465: 'thinly',
#  466: 'negligent',
#  467: 'chains',
#  468: 'rated',
#  469: 'than',
#  470: 'Tasted',
#  471: 'coupons',
#  472: 'transcendant',
#  473: 'Large',
#  474: 'metro',
#  475: 'common',
#  476: 'review',
#  477: 'located',
#  478: 'yukon',
#  479: 'big',
#  480: 'Awesome',
#  481: 'needs',
#  482: 'Really',
#  483: 'carbs',
#  484: 'experience',
#  485: 'sub',
#  486: '``',
#  487: 'enjoyed',
#  488: 'wines',
#  489: 'forty',
#  490: 'Cute',
#  491: 'anymore',
#  492: 'Maybe',
#  493: 'dirty',
#  494: 'Cape',
#  495: 'empty',
#  496: 'BEST',
#  497: 'bars',
#  498: 'human',
#  499: 'cute',
#  500: 'party',
#  501: 'donut',
#  502: 'stir',
#  503: 'hot',
#  504: 'theft',
#  505: 'blow',
#  506: 'touch',
#  507: 'quit',
#  508: 'hooked',
#  509: 'overcooked',
#  510: 'Perfect',
#  511: 'Last',
#  512: 'prepared',
#  513: 'truly',
#  514: 'First',
#  515: 'styrofoam',
#  516: 'Firehouse',
#  517: 'waiter',
#  518: 'Never',
#  519: 'I',
#  520: 'pats',
#  521: 'strawberry',
#  522: 'hankering',
#  523: 'power',
#  524: 'cheese',
#  525: 'Magazine',
#  526: 'accordingly',
#  527: 'Bar',
#  528: 'beautiful',
#  529: 'refried',
#  530: 'highlighted',
#  531: 'informative',
#  532: 'barely',
#  533: 'BBQ',
#  534: 'condiment',
#  535: 'satisfied',
#  536: 'godfathers',
#  537: '%',
#  538: 'To',
#  539: 'tummy',
#  540: 'Sushi',
#  541: 'Horrible',
#  542: 'tapas',
#  543: 'Tried',
#  544: 'HAD',
#  545: 'took',
#  546: 'Classy/warm',
#  547: 'drastically',
#  548: 'pork',
#  549: 'bakery',
#  550: 'Brushfire',
#  551: 'whether',
#  552: 'Friend',
#  553: 'crêpe',
#  554: 'Strike',
#  555: 'claimed',
#  556: 'Based',
#  557: 'refrained',
#  558: 'Mandalay',
#  559: 'Try',
#  560: 'vodka',
#  561: 'getting',
#  562: 'unprofessional',
#  563: 'setting',
#  564: 'Pineapple',
#  565: 'She',
#  566: 'thru',
#  567: 'lukewarm',
#  568: 'OVERPRICED',
#  569: 'few',
#  570: 'Luke',
#  571: 'taco',
#  572: 'least',
#  573: 'must',
#  574: 'very',
#  575: 'sides',
#  576: 'cafe',
#  577: 'waited',
#  578: 'Join',
#  579: 'Took',
#  580: 'coffee',
#  581: 'favor',
#  582: '..there',
#  583: 'shirt',
#  584: 'loved',
#  585: 'salads',
#  586: 'At',
#  587: 'family',
#  588: 'piece',
#  589: 'crusty',
#  590: 'reviews',
#  591: 'OMG',
#  592: 'Eclectic',
#  593: 'dates',
#  594: 'meats',
#  595: 'Filet',
#  596: 'properly',
#  597: 'Greek',
#  598: 'left',
#  599: 'value',
#  600: 'every',
#  601: 'recently',
#  602: 'bottom',
#  603: 'rings',
#  604: 'NONE',
#  605: 'WHAT',
#  606: 'otherwise',
#  607: 'Highly',
#  608: 'fear',
#  609: 'Any',
#  610: 'style',
#  611: 'walls',
#  612: 'spice',
#  613: 'probably',
#  614: 'tailored',
#  615: 'flavor',
#  616: 'boyfriend',
#  617: 'largely',
#  618: 'GREAT',
#  619: 'vain',
#  620: 'creamy',
#  621: 'Thoroughly',
#  622: 'dish',
#  623: 'dessert',
#  624: '10',
#  625: 'teeth',
#  626: '&',
#  627: '4.00',
#  628: 'looks',
#  629: 'sangria',
#  630: 'Are',
#  631: 'liked',
#  632: 'rolls',
#  633: 'how',
#  634: 'juries',
#  635: 'Denny',
#  636: 'Macarons',
#  637: 'WASTE',
#  638: 'medium',
#  639: 'leave',
#  640: 'excellent',
#  641: 'kind',
#  642: 'capers',
#  643: 'thick',
#  644: 'mood',
#  645: 'complaints',
#  646: 'pop',
#  647: ',',
#  648: 'cashier',
#  649: 'disaster',
#  650: 'CONCLUSION',
#  651: 'tacos',
#  652: 'Las',
#  653: 'MANY',
#  654: 'veal',
#  655: 'degree',
#  656: 'strangers',
#  657: 'whole',
#  658: 'register',
#  659: 'rinse',
#  660: 'those',
#  661: 'Will',
#  662: 'gratitude',
#  663: 'outshining',
#  664: 'vegan/veggie',
#  665: 'from',
#  666: 'drenched',
#  667: 'huevos',
#  668: 'Joey',
#  669: 'Ninja',
#  670: 'likes',
#  671: 'sound',
#  672: 'sign',
#  673: 'BETTER',
#  674: 'relocated',
#  675: 'Extremely',
#  676: 'tater',
#  677: 'unbelievable',
#  678: 'different',
#  679: 'downtown',
#  680: 'constructed',
#  681: 'gristle',
#  682: 'Bisque',
#  683: 'Han',
#  684: 'opinion',
#  685: 'spotty',
#  686: 'boiled',
#  687: 'fellow',
#  688: 'unexperienced',
#  689: 'recommendation',
#  690: 'finally',
#  691: 'point',
#  692: 'beers',
#  693: 'pneumatic',
#  694: 'affordable',
#  695: 'mac',
#  696: 'returning',
#  697: 'Total',
#  698: 'Heart',
#  699: 'angry',
#  700: 'sergeant',
#  701: 'his',
#  702: 'blame',
#  703: 'dirty-',
#  704: 'call',
#  705: 'funny',
#  706: 'imagine',
#  707: 'weekend',
#  708: '?',
#  709: 'rest',
#  710: 'EXPERIENCE',
#  711: 'seems',
#  712: 'shopping',
#  713: 'colder',
#  714: 'bowl',
#  715: 'served',
#  716: 'dark',
#  717: 'fo',
#  718: 'bodes',
#  719: 'OK',
#  720: 'awful',
#  721: 'pumpkin',
#  722: 'promptly',
#  723: 'milk',
#  724: 'pictures',
#  725: 'vibe',
#  726: 'sause',
#  727: 'meet',
#  728: 'easily',
#  729: 'consider',
#  730: 'NYC',
#  731: 'best',
#  732: 'must-stop',
#  733: 'Everyone',
#  734: 'Aria',
#  735: 'stood',
#  736: 'driest',
#  737: 'redeeming',
#  738: 'Left',
#  739: 'ate',
#  740: 'Service',
#  741: 'Hot',
#  742: 'Phenomenal',
#  743: 'round',
#  744: 'overall',
#  745: 'perpared',
#  746: 'today',
#  747: 'for',
#  748: 'fireball',
#  749: 'descriptions',
#  750: 'friends',
#  751: 'greens',
#  752: 'hardly',
#  753: 'lighter',
#  754: 'on',
#  755: 'Check',
#  756: 'In',
#  757: 'homemade',
#  758: 'awesome',
#  759: 'reasonable',
#  760: 'sat',
#  761: 'Pretty',
#  762: 'was',
#  763: 'patty',
#  764: 'bye',
#  765: 'profound',
#  766: 'like',
#  767: 'recommended',
#  768: '6',
#  769: 'completely',
#  770: 'disgraceful',
#  771: 'selection',
#  772: 'Experience',
#  773: 'cheesecurds',
#  774: 'wire',
#  775: 'nice',
#  776: 'puréed',
#  777: 'stretch',
#  778: 'Coming',
#  779: 'handled',
#  780: 'soup',
#  781: 'spot',
#  782: 'smelled',
#  783: 'that',
#  784: 'Insults',
#  785: '!',
#  786: 'pay',
#  787: 'middle',
#  788: 'fails',
#  789: 'crawfish',
#  790: 'If',
#  791: 'get',
#  792: 'covers',
#  793: 'ended',
#  794: 'do',
#  795: '2007',
#  796: 'happier',
#  797: 'breakfast',
#  798: 'bigger',
#  799: 'awkward',
#  800: 'wall',
#  801: 'white',
#  802: 'falling',
#  803: 'ball',
#  804: 'burgers',
#  805: 'company',
#  806: 'unique',
#  807: 'cashew',
#  808: 'perfection',
#  809: 'relationship',
#  810: 'flat',
#  811: 'disgrace',
#  812: 'Prices',
#  813: 'sals',
#  814: 'OF',
#  815: 'velvet',
#  816: 'customers',
#  817: 'heart',
#  818: 'considering',
#  819: 'Ample',
#  820: 'thumbs',
#  821: 'fucking',
#  822: 'correct',
#  823: 'Gourmet',
#  824: 'poorly',
#  825: 'Disappointing',
#  826: 'most',
#  827: 'disapppointment',
#  828: '...',
#  829: 'hardest',
#  830: 'soundtrack',
#  831: 'guacamole',
#  832: 'pissd',
#  833: 'Hunan',
#  834: 'maintaining',
#  835: 'eel',
#  836: 'sucks',
#  837: 'Attack',
#  838: 'pleasure',
#  839: '*heart*',
#  840: 'store',
#  841: 'uploaded',
#  842: 'head',
#  843: 'course',
#  844: 'year',
#  845: 'gloves.Everything',
#  846: 'Francisco',
#  847: 'pleasant',
#  848: 'Same',
#  849: 'although',
#  850: 'surprise',
#  851: 'Please',
#  852: 'extraordinary',
#  853: 'yay',
#  854: 'cause',
#  855: 'TOTAL',
#  856: 'menu/',
#  857: 'deal',
#  858: '90',
#  859: 'stop',
#  860: 'describing',
#  861: 'Seriously',
#  862: 'Mellow',
#  863: 'reservation',
#  864: 'apologize',
#  865: 'similar',
#  866: 'craving',
#  867: 'slow',
#  868: '.very',
#  869: 'sharply',
#  870: 'rancheros',
#  871: 'night',
#  872: 'Crust',
#  873: 'walked',
#  874: 'supposed',
#  875: 'soooo',
#  876: 'grab',
#  877: 'tenders',
#  878: 'ventilation',
#  879: 'boy',
#  880: 'lunch',
#  881: 'Best',
#  882: 'showed',
#  883: 'recall',
#  884: 'May',
#  885: 'at',
#  886: 'sense',
#  887: 'STALE',
#  888: 'Bloody',
#  889: 'Caballero',
#  890: 'chickens',
#  891: 'friend',
#  892: 'struggle',
#  893: 'sorely',
#  894: 'thanks',
#  895: 'mein',
#  896: 'concept',
#  897: 'beans',
#  898: '.the',
#  899: 'occasions',
#  900: 'roasted',
#  901: 'Come',
#  902: 'several',
#  903: 'number',
#  904: 'saganaki',
#  905: 'Yelpers',
#  906: 'INCONSIDERATE',
#  907: 'she',
#  908: 'once',
#  909: 'Hawaiian',
#  910: 'recommend',
#  911: 'When',
#  912: 'Third',
#  913: 'binge',
#  914: 'chewy',
#  915: 'pancakes',
#  916: 'their',
#  917: 'remember',
#  918: 'Buffet',
#  919: 'Unfortunately',
#  920: 'Green',
#  921: 'reviewer',
#  922: 'tell',
#  923: 'edible',
#  924: 'leftover',
#  925: 'still',
#  926: 'came',
#  927: 'pizzas',
#  928: 'pub',
#  929: 'Noca',
#  930: 'accident',
#  931: '70+',
#  932: 'Steak',
#  933: 'tiny',
#  934: 'baby',
#  935: 'neither',
#  936: 'Yeah',
#  937: 'burned',
#  938: 'everyone',
#  939: 'Toast',
#  940: 'ribeye',
#  941: 'red',
#  942: 'mom',
#  943: 'Google',
#  944: 'boba',
#  945: 'acknowledged',
#  946: 'zero',
#  947: 'presentation',
#  948: 'enough..',
#  949: 'quite',
#  950: 'frustrated',
#  951: 'peanuts',
#  952: 'gotten',
#  953: 'ratio',
#  954: 'places',
#  955: 'box',
#  956: 'nicest',
#  957: '30',
#  958: 'killer',
#  959: 'SHOULD',
#  960: 'Vegas',
#  961: 'missing',
#  962: 'privileged',
#  963: 'bathrooms',
#  964: 'desired',
#  965: 'less',
#  966: 'relaxed',
#  967: 'usual',
#  968: 'blows',
#  969: 'Gringos',
#  970: 'Khao',
#  971: 'off',
#  972: 'concern',
#  973: 'Sunday',
#  974: 'light',
#  975: 'me..Bunch',
#  976: 'airport',
#  977: 'our',
#  978: 'vinaigrette',
#  979: 'actual',
#  980: 'sit-down',
#  981: 'strip',
#  982: 'silently',
#  983: 'fiancé',
#  984: 'blown',
#  985: 'combination',
#  986: 'batter',
#  987: 'Steiners',
#  988: 'via',
#  989: 'say',
#  990: 'Very',
#  991: 'dead',
#  992: "'re",
#  993: 'and',
#  994: 'you',
#  995: 'summary',
#  996: 'opened',
#  997: 'Egg',
#  998: 'wanted',
#  999: 'lots',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    '''創建一個vector'''
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index_dic[word]] += 1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
